# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Producing the first image

# %%
img = np.random.rand(200,200)*256

# %%
img
# Out:
# array([[121.77903074, 103.46791033, 221.23005959, ..., 112.37114173,
#          14.59589454, 153.51679084],
#        [ 52.58486264, 141.68714928, 187.81832415, ...,  14.7110211 ,
#         231.72748358,  58.55279838],
#        [130.61237106,  51.71278847, 133.92534746, ...,  13.99683293,
#         163.94486472, 206.36152513],
#        ...,
#        [249.67612285,  15.45219934, 110.16938709, ..., 150.03402206,
#         133.4412305 , 139.36934059],
#        [159.84485186, 157.0509846 , 146.68057891, ..., 131.14905249,
#         237.75121817, 227.10375826],
#        [  5.60228854, 188.588543  ,  10.73378654, ..., 239.08449632,
#         184.38574399,   7.27902491]])

# %%
cv2.imwrite('first-try-img.png', img)
plt.imshow(img, cmap='gray')

# %%
tabla = cv2.imread('Tabla.jpg')
tabla = cv2.cvtColor(tabla, cv2.COLOR_BGR2RGB)
plt.imshow(tabla)

# %%
plt.imshow(img, cmap='coolwarm')

# %% [markdown]
# # Producing two patches in the image
# One black patch and one white patch

# %%
patched_image = cv2.imread('first-try-img.png',1)
plt.imshow(patched_image)

# %%
patched_image.shape
# Out:
# (200, 200, 3)

# %%
type(patched_image)
# Out:
# numpy.ndarray

# %%
patched_image[50:100,50:100,:] = np.zeros((50,50,3))
patched_image[100:150,100:150,:] = np.ones((50,50,3))*255

# %%
plt.imshow(patched_image)

# %% [markdown]
# # Print an image of your choice and crop it

# %%
my_img = cv2.imread('bus.jpg')
img_amar = cv2.cvtColor(my_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(my_img)

# %%
plt.imshow(img_amar)

# %%
plt.imshow(img_amar[440:500,320:800]) ## Printing the route of the bus
# plt.imshow(img_amar[70:170,720:820])

# %% [markdown]
# # THANK YOU
